# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

from utils.SVM import SVM
from utils.utils import load_iris_binary, split_db_2to1

# %%
D, L = load_iris_binary()
(DTR, LTR), (DVAL, LVAL) = split_db_2to1(D, L)

# %%
svm = SVM(K=0, C=1, kernel='rbf', d=2, c=1, gamma=10)

svm.fit(DTR, LTR)

pred = svm.predict(DVAL)
err, cm, _, _ = svm.evaluate(LVAL)

print(f'Error: {err}')
print(f'Confusion Matrix:\n{cm}')
# Out:
# Error: 0.11764705882352944
# Confusion Matrix:
# [[15.  1.]
#  [ 3. 15.]]
